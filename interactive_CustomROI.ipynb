# %%
# %matplotlib widget
from plantcv import plantcv as pcv
import numpy as np

# %%
pcv.params.debug = "plot"
img, filename, path = pcv.readimage(filename="imgs/GN2_5569.JPG")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
drawer_rgb = pcv.roi.CustomROI(img, figsize=(12,6))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#pcv.params.debug = "print"
roi_contour, roi_hierarchy = pcv.roi.custom(img=img, vertices = drawer_rgb.points)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(drawer_rgb.points)
# Out:
# [(1626, 1925), (1264, 1514), (1675, 1006), (2264, 1631), (2135, 1919)]

# %% [markdown]
# # Using interactive tools for multi-ROI workflows

# %%
img2, filename, path = pcv.readimage(filename="imgs/multi_arabidopsis.jpg")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
drawer_rgb2 = pcv.roi.CustomROI(img2, figsize=(12,6))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
drawer_rgb2.points
# Out:
# [(880, 238),
#  (1288, 225),
#  (1746, 221),
#  (2213, 238),
#  (392, 755),
#  (854, 705),
#  (1342, 755),
#  (1700, 747),
#  (2235, 743),
#  (446, 1180),
#  (871, 1218),
#  (1321, 1206),
#  (1780, 1227),
#  (2201, 1260),
#  (425, 1656),
#  (842, 1673),
#  (1313, 1660),
#  (1784, 1664)]

# %%
rois, roi_hierarchy = pcv.roi.multi(img=img2, coord=drawer_rgb2.points, radius=100)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
