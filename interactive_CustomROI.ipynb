# %%
from plantcv import plantcv as pcv

# %%
pcv.params.debug = "plot"
# %matplotlib notebook
img, filename, path = pcv.readimage(filename="imgs/GN2_5569.JPG")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
drawer_rgb = pcv.roi.CustomROI(img, figsize=(12,6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/vt/dq1xlx752nb2xh5zs3y3wb200000gp/T/ipykernel_41723/673227323.py in <module>
# ----> 1 drawer_rgb = pcv.roi.CustomROI(img, figsize=(12,6))
#
# AttributeError: module 'plantcv.plantcv.roi' has no attribute 'CustomROI'

# %%
#pcv.params.debug = "print"
roi_contour, roi_hierarchy = pcv.roi.custom(img=img, vertices = drawer_rgb.points)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(drawer_rgb.points)
# Out:
# [(1192, 1812), (1339, 1144), (2166, 1114), (2209, 1886)]
